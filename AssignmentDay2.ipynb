# %% [markdown]
# <a href="https://colab.research.google.com/github/stymgupta/assignment2/blob/main/AssignmentDay2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing The Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load DataSet

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Finding DataTypes of all the columns

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ## Plotting JointPlot for all floatvalues types

# %%
## Joint-plot

sns.jointplot(x='sepal_length', y='sepal_width', data=df, kind='hex')

# %%
## Joint-plot

sns.jointplot(x='sepal_length', y='petal_length', data=df, kind='reg')

# %%
## Joint-plot

sns.jointplot(x='petal_length', y='petal_width', data=df, kind='hist')

# %%
## Joint-plot

sns.jointplot(x='sepal_width', y='petal_width', data=df, kind='scatter')

# %% [markdown]
# ## Pairplot for all correlative values

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue = 'species')

# %% [markdown]
# ## Counting Number of Flower Species

# %%
count=df['species'].value_counts()
count
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %% [markdown]
# ## Plotting PieChart

# %%
plt.pie(count, labels=['virginica','versicolor','setosa'], radius=1.4,autopct='%0.1f%%',shadow=True, startangle=45, explode=[0.1,0.1,0.1])
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Plotting Distplot, Displot and Histplot

# %%
#distplot
sns.distplot(df['sepal_length'])

# %%
#distplot
sns.distplot(df['petal_length'])

# %%
#displot
sns.displot(df['sepal_width'])

# %%
#histplot
sns.histplot(df['petal_width'])
